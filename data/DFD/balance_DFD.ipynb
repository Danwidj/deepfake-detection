# %% [markdown]
# # DFD Dataset Balancing
#
# This notebook analyzes and balances the DeepFake Detection (DFD) dataset by matching original videos with their manipulated counterparts.

# %%
import os
from collections import defaultdict
import shutil

# %%
# Define paths
original_path = '../DFD/DFD_original_sequences'
manipulated_path = '../DFD/DFD_manipulated_sequences'

# Get all files
original_files = os.listdir(original_path)
manipulated_files = os.listdir(manipulated_path)

print(f"Total original videos: {len(original_files)}")
print(f"Total manipulated videos: {len(manipulated_files)}")
# Out:
# Total original videos: 364
# Total manipulated videos: 3068

# %%
def get_base_name(filename):
    """Extract the base name from the video filename (removing ID and hash if present)"""
    if not filename.endswith('.mp4'):
        return None
        
    parts = filename.split('__')
    
    if len(parts) == 2:  # Original video (format: XX__name.mp4)
        # Keep the ID and base name for original videos
        return filename.replace('.mp4', '')
    elif len(parts) == 3:  # Manipulated video (format: XX_YY__name__HASH.mp4)
        # For manipulated, extract the source ID and base name
        id_parts = parts[0].split('_')
        if len(id_parts) >= 1:
            source_id = id_parts[0]  # Get the first ID (source ID)
            return f"{source_id}__{parts[1]}"  # Combine source ID with base name
    return None

# Create dictionaries to store videos by their base names
original_dict = defaultdict(list)
manipulated_dict = defaultdict(list)

# Categorize original videos
for f in original_files:
    base_name = get_base_name(f)
    if base_name:
        original_dict[base_name].append(f)

# Categorize manipulated videos
for f in manipulated_files:
    base_name = get_base_name(f)
    if base_name:
        manipulated_dict[base_name].append(f)

# Find matching pairs
matching_bases = set(original_dict.keys()) & set(manipulated_dict.keys())

print(f"\nUnique original video types: {len(original_dict)}")
print(f"Unique manipulated video types: {len(manipulated_dict)}")
print(f"Matching video types: {len(matching_bases)}")

# Print some examples to verify
print("\nExample categorizations:")
for i, (base, files) in enumerate(original_dict.items()):
    if i >= 3:  # Only show first 3 examples
        break
    print(f"\nBase name: {base}")
    print(f"Original: {files[0]}")
    if base in manipulated_dict:
        print(f"Manipulated: {manipulated_dict[base][0]}")
# Out:
# Unique original video types: 363
# Unique manipulated video types: 358
# Matching video types: 358
#
# Example categorizations:
#
# Base name: 07__exit_phone_room
# Original: 07__exit_phone_room.mp4
# Manipulated: 07_21__exit_phone_room__K7KXUHMU.mp4
#
# Base name: 09__kitchen_pan
# Original: 09__kitchen_pan.mp4
# Manipulated: 09_21__kitchen_pan__Z8H2TRCI.mp4
#
# Base name: 02__walking_down_street_outside_angry
# Original: 02__walking_down_street_outside_angry.mp4
# Manipulated: 02_07__walking_down_street_outside_angry__O4SXNLRL.mp4

# %%
# Analyze the matches in detail
print("Detailed matching analysis:")
print("-" * 50)

for base in sorted(matching_bases):
    orig_count = len(original_dict[base])
    manip_count = len(manipulated_dict[base])
    print(f"{base}:")
    print(f"  Original videos: {orig_count}")
    print(f"  Manipulated versions: {manip_count}")
    
    # Show some examples
    if orig_count > 0 and manip_count > 0:
        print(f"  Example original: {original_dict[base][0]}")
        print(f"  Example manipulated: {manipulated_dict[base][0]}")
    print()
# Out:
# Detailed matching analysis:
# --------------------------------------------------
# 01__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 01__exit_phone_room.mp4
#   Example manipulated: 01_11__exit_phone_room__4OJNJLOO.mp4
#
# 01__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 01__hugging_happy.mp4
#   Example manipulated: 01_15__hugging_happy__02HILKYO.mp4
#
# 01__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 01__kitchen_pan.mp4
#   Example manipulated: 01_21__kitchen_pan__03X7CELV.mp4
#
# 01__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 01__kitchen_still.mp4
#   Example manipulated: 01_03__kitchen_still__JZUXXFRB.mp4
#
# 01__meeting_serious:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 01__meeting_serious.mp4
#   Example manipulated: 01_20__meeting_serious__D8GWGO2A.mp4
#
# 01__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 01__outside_talking_pan_laughing.mp4
#   Example manipulated: 01_15__outside_talking_pan_laughing__02HILKYO.mp4
#
# 01__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 01__outside_talking_still_laughing.mp4
#   Example manipulated: 01_02__outside_talking_still_laughing__YVGY8LOK.mp4
#
# 01__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 01__podium_speech_happy.mp4
#   Example manipulated: 01_11__podium_speech_happy__WIZ7GKOD.mp4
#
# 01__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 01__secret_conversation.mp4
#   Example manipulated: 01_20__secret_conversation__6UBMLXK3.mp4
#
# 01__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 01__talking_against_wall.mp4
#   Example manipulated: 01_11__talking_against_wall__4OJNJLOO.mp4
#
# 01__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 01__talking_angry_couch.mp4
#   Example manipulated: 01_11__talking_angry_couch__FAFWDR4W.mp4
#
# 01__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 01__walk_down_hall_angry.mp4
#   Example manipulated: 01_04__walk_down_hall_angry__0XUW13RW.mp4
#
# 01__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 01__walking_and_outside_surprised.mp4
#   Example manipulated: 01_14__walking_and_outside_surprised__01YF7VQM.mp4
#
# 01__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 1
#   Example original: 01__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 01_02__walking_down_indoor_hall_disgust__YVGY8LOK.mp4
#
# 01__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 01__walking_down_street_outside_angry.mp4
#   Example manipulated: 01_15__walking_down_street_outside_angry__02HILKYO.mp4
#
# 01__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 01__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 01_27__walking_outside_cafe_disgusted__ZYCZ30C0.mp4
#
# 02__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 18
#   Example original: 02__exit_phone_room.mp4
#   Example manipulated: 02_14__exit_phone_room__3IUBEKCT.mp4
#
# 02__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 02__hugging_happy.mp4
#   Example manipulated: 02_04__hugging_happy__SUIZOXAJ.mp4
#
# 02__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 17
#   Example original: 02__kitchen_pan.mp4
#   Example manipulated: 02_07__kitchen_pan__34PVT42V.mp4
#
# 02__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 02__kitchen_still.mp4
#   Example manipulated: 02_07__kitchen_still__TBLYQBIY.mp4
#
# 02__meeting_serious:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 02__meeting_serious.mp4
#   Example manipulated: 02_07__meeting_serious__O4SXNLRL.mp4
#
# 02__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 17
#   Example original: 02__outside_talking_pan_laughing.mp4
#   Example manipulated: 02_15__outside_talking_pan_laughing__I8G2LWD1.mp4
#
# 02__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 02__outside_talking_still_laughing.mp4
#   Example manipulated: 02_04__outside_talking_still_laughing__8CH7R4LW.mp4
#
# 02__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 02__podium_speech_happy.mp4
#   Example manipulated: 02_15__podium_speech_happy__I8G2LWD1.mp4
#
# 02__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 02__secret_conversation.mp4
#   Example manipulated: 02_25__secret_conversation__Z7FQ69VP.mp4
#
# 02__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 02__talking_against_wall.mp4
#   Example manipulated: 02_15__talking_against_wall__QYSDT9SO.mp4
#
# 02__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 02__talking_angry_couch.mp4
#   Example manipulated: 02_13__talking_angry_couch__AROBAY8R.mp4
#
# 02__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 02__walk_down_hall_angry.mp4
#   Example manipulated: 02_06__walk_down_hall_angry__0M6JNS5D.mp4
#
# 02__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 17
#   Example original: 02__walking_and_outside_surprised.mp4
#   Example manipulated: 02_15__walking_and_outside_surprised__MZWH8ATN.mp4
#
# 02__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 02__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 02_15__walking_down_indoor_hall_disgust__HTG660F8.mp4
#
# 02__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 02__walking_down_street_outside_angry.mp4
#   Example manipulated: 02_07__walking_down_street_outside_angry__O4SXNLRL.mp4
#
# 02__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 02__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 02_13__walking_outside_cafe_disgusted__CP5HFV3K.mp4
#
# 03__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 18
#   Example original: 03__exit_phone_room.mp4
#   Example manipulated: 03_14__exit_phone_room__0O9TTCJT.mp4
#
# 03__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 03__hugging_happy.mp4
#   Example manipulated: 03_13__hugging_happy__GBYWJW06.mp4
#
# 03__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 18
#   Example original: 03__kitchen_pan.mp4
#   Example manipulated: 03_14__kitchen_pan__ZC2KYASW.mp4
#
# 03__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 03__kitchen_still.mp4
#   Example manipulated: 03_15__kitchen_still__AIOM1U5V.mp4
#
# 03__meeting_serious:
#   Original videos: 1
#   Manipulated versions: 18
#   Example original: 03__meeting_serious.mp4
#   Example manipulated: 03_02__meeting_serious__ZESUJMM7.mp4
#
# 03__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 03__outside_talking_pan_laughing.mp4
#   Example manipulated: 03_15__outside_talking_pan_laughing__AIOM1U5V.mp4
#
# 03__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 03__outside_talking_still_laughing.mp4
#   Example manipulated: 03_07__outside_talking_still_laughing__IFSURI9X.mp4
#
# 03__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 17
#   Example original: 03__podium_speech_happy.mp4
#   Example manipulated: 03_07__podium_speech_happy__6PHZRQ4H.mp4
#
# 03__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 03__secret_conversation.mp4
#   Example manipulated: 03_14__secret_conversation__KJ221YN0.mp4
#
# 03__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 17
#   Example original: 03__talking_against_wall.mp4
#   Example manipulated: 03_07__talking_against_wall__F0YYEA5W.mp4
#
# 03__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 03__talking_angry_couch.mp4
#   Example manipulated: 03_04__talking_angry_couch__T04P6ELC.mp4
#
# 03__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 03__walk_down_hall_angry.mp4
#   Example manipulated: 03_07__walk_down_hall_angry__6PHZRQ4H.mp4
#
# 03__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 03__walking_and_outside_surprised.mp4
#   Example manipulated: 03_27__walking_and_outside_surprised__KWGI1LSZ.mp4
#
# 03__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 03__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 03_18__walking_down_indoor_hall_disgust__UEC1BI8E.mp4
#
# 03__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 03__walking_down_street_outside_angry.mp4
#   Example manipulated: 03_02__walking_down_street_outside_angry__QH3Y0IG0.mp4
#
# 03__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 03__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 03_12__walking_outside_cafe_disgusted__D7G6YJON.mp4
#
# 04__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 04__exit_phone_room.mp4
#   Example manipulated: 04_01__exit_phone_room__0XUW13RW.mp4
#
# 04__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 04__kitchen_pan.mp4
#   Example manipulated: 04_26__kitchen_pan__MS2MLJP1.mp4
#
# 04__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 04__kitchen_still.mp4
#   Example manipulated: 04_12__kitchen_still__B6YJ9IW1.mp4
#
# 04__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 04__outside_talking_pan_laughing.mp4
#   Example manipulated: 04_02__outside_talking_pan_laughing__8CH7R4LW.mp4
#
# 04__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 04__outside_talking_still_laughing.mp4
#   Example manipulated: 04_07__outside_talking_still_laughing__QKCCFKBT.mp4
#
# 04__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 04__podium_speech_happy.mp4
#   Example manipulated: 04_07__podium_speech_happy__M2NBCLFR.mp4
#
# 04__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 04__secret_conversation.mp4
#   Example manipulated: 04_21__secret_conversation__PRCQUMY8.mp4
#
# 04__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 04__talking_against_wall.mp4
#   Example manipulated: 04_15__talking_against_wall__46TJ9IOJ.mp4
#
# 04__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 04__talking_angry_couch.mp4
#   Example manipulated: 04_15__talking_angry_couch__46TJ9IOJ.mp4
#
# 04__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 04__walk_down_hall_angry.mp4
#   Example manipulated: 04_02__walk_down_hall_angry__8CH7R4LW.mp4
#
# 04__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 04__walking_down_street_outside_angry.mp4
#   Example manipulated: 04_26__walking_down_street_outside_angry__WX836VLY.mp4
#
# 04__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 04__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 04_27__walking_outside_cafe_disgusted__2CCI2ND1.mp4
#
# 05__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 05__exit_phone_room.mp4
#   Example manipulated: 05_08__exit_phone_room__YN1Q9TER.mp4
#
# 05__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 05__hugging_happy.mp4
#   Example manipulated: 05_08__hugging_happy__FBICSP2C.mp4
#
# 05__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 05__kitchen_pan.mp4
#   Example manipulated: 05_08__kitchen_pan__BGI70HJ5.mp4
#
# 05__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 05__kitchen_still.mp4
#   Example manipulated: 05_16__kitchen_still__053HPS1G.mp4
#
# 05__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 05__outside_talking_pan_laughing.mp4
#   Example manipulated: 05_08__outside_talking_pan_laughing__FBICSP2C.mp4
#
# 05__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 05__podium_speech_happy.mp4
#   Example manipulated: 05_28__podium_speech_happy__2DK5X0Y0.mp4
#
# 05__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 05__talking_against_wall.mp4
#   Example manipulated: 05_17__talking_against_wall__M3H96PDQ.mp4
#
# 05__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 05__walk_down_hall_angry.mp4
#   Example manipulated: 05_16__walk_down_hall_angry__V7BK27TX.mp4
#
# 05__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 05__walking_down_street_outside_angry.mp4
#   Example manipulated: 05_17__walking_down_street_outside_angry__M3H96PDQ.mp4
#
# 05__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 05__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 05_16__walking_outside_cafe_disgusted__O56DDU3S.mp4
#
# 06__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 06__exit_phone_room.mp4
#   Example manipulated: 06_15__exit_phone_room__QRCD27P8.mp4
#
# 06__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 06__hugging_happy.mp4
#   Example manipulated: 06_27__hugging_happy__S3T7SK9O.mp4
#
# 06__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 06__kitchen_pan.mp4
#   Example manipulated: 06_15__kitchen_pan__E98QYYXO.mp4
#
# 06__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 06__kitchen_still.mp4
#   Example manipulated: 06_14__kitchen_still__8U9ULZDT.mp4
#
# 06__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 06__outside_talking_pan_laughing.mp4
#   Example manipulated: 06_18__outside_talking_pan_laughing__MVXBDKGB.mp4
#
# 06__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 06__outside_talking_still_laughing.mp4
#   Example manipulated: 06_18__outside_talking_still_laughing__M36D0OJT.mp4
#
# 06__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 06__podium_speech_happy.mp4
#   Example manipulated: 06_26__podium_speech_happy__L5BVR5L9.mp4
#
# 06__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 06__talking_against_wall.mp4
#   Example manipulated: 06_03__talking_against_wall__1IXGY2FK.mp4
#
# 06__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 06__talking_angry_couch.mp4
#   Example manipulated: 06_02__talking_angry_couch__J1W9R0NG.mp4
#
# 06__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 06__walk_down_hall_angry.mp4
#   Example manipulated: 06_03__walk_down_hall_angry__1IXGY2FK.mp4
#
# 06__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 06__walking_and_outside_surprised.mp4
#   Example manipulated: 06_21__walking_and_outside_surprised__058I9NIZ.mp4
#
# 06__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 06__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 06_04__walking_down_indoor_hall_disgust__ZK95PQDE.mp4
#
# 06__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 06__walking_down_street_outside_angry.mp4
#   Example manipulated: 06_12__walking_down_street_outside_angry__3K21NFNM.mp4
#
# 06__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 06__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 06_26__walking_outside_cafe_disgusted__L5BVR5L9.mp4
#
# 07__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 07__exit_phone_room.mp4
#   Example manipulated: 07_21__exit_phone_room__K7KXUHMU.mp4
#
# 07__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 17
#   Example original: 07__hugging_happy.mp4
#   Example manipulated: 07_14__hugging_happy__P9QFO50U.mp4
#
# 07__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 07__kitchen_pan.mp4
#   Example manipulated: 07_04__kitchen_pan__M2NBCLFR.mp4
#
# 07__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 07__kitchen_still.mp4
#   Example manipulated: 07_26__kitchen_still__FGNGC2GT.mp4
#
# 07__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 07__outside_talking_pan_laughing.mp4
#   Example manipulated: 07_12__outside_talking_pan_laughing__KAG65PEE.mp4
#
# 07__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 07__outside_talking_still_laughing.mp4
#   Example manipulated: 07_02__outside_talking_still_laughing__1ZE4HC06.mp4
#
# 07__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 07__podium_speech_happy.mp4
#   Example manipulated: 07_03__podium_speech_happy__CDSNLDQ8.mp4
#
# 07__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 07__secret_conversation.mp4
#   Example manipulated: 07_03__secret_conversation__IFSURI9X.mp4
#
# 07__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 07__talking_against_wall.mp4
#   Example manipulated: 07_02__talking_against_wall__U7DEOZNV.mp4
#
# 07__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 07__talking_angry_couch.mp4
#   Example manipulated: 07_02__talking_angry_couch__1H07DFQJ.mp4
#
# 07__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 07__walk_down_hall_angry.mp4
#   Example manipulated: 07_02__walk_down_hall_angry__U7DEOZNV.mp4
#
# 07__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 07__walking_down_street_outside_angry.mp4
#   Example manipulated: 07_21__walking_down_street_outside_angry__MKU99DVX.mp4
#
# 07__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 07__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 07_02__walking_outside_cafe_disgusted__1H07DFQJ.mp4
#
# 08__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 08__exit_phone_room.mp4
#   Example manipulated: 08_28__exit_phone_room__KXO8S7OP.mp4
#
# 08__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 08__kitchen_pan.mp4
#   Example manipulated: 08_28__kitchen_pan__6HFK6PB4.mp4
#
# 08__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 08__kitchen_still.mp4
#   Example manipulated: 08_05__kitchen_still__UNN7ZGKO.mp4
#
# 08__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 08__outside_talking_pan_laughing.mp4
#   Example manipulated: 08_28__outside_talking_pan_laughing__HIOU8Z8I.mp4
#
# 08__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 08__outside_talking_still_laughing.mp4
#   Example manipulated: 08_17__outside_talking_still_laughing__JZYRLJ8T.mp4
#
# 08__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 08__podium_speech_happy.mp4
#   Example manipulated: 08_28__podium_speech_happy__KXO8S7OP.mp4
#
# 08__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 08__talking_against_wall.mp4
#   Example manipulated: 08_17__talking_against_wall__ISS1V0B1.mp4
#
# 08__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 08__walk_down_hall_angry.mp4
#   Example manipulated: 08_17__walk_down_hall_angry__QOX5NWIJ.mp4
#
# 08__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 1
#   Example original: 08__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 08_28__walking_outside_cafe_disgusted__GQN9WHLD.mp4
#
# 09__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 09__exit_phone_room.mp4
#   Example manipulated: 09_18__exit_phone_room__3VP8836C.mp4
#
# 09__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 09__kitchen_pan.mp4
#   Example manipulated: 09_21__kitchen_pan__Z8H2TRCI.mp4
#
# 09__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 09__outside_talking_pan_laughing.mp4
#   Example manipulated: 09_01__outside_talking_pan_laughing__SJZRV69J.mp4
#
# 09__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 09__outside_talking_still_laughing.mp4
#   Example manipulated: 09_03__outside_talking_still_laughing__8DTEGQ54.mp4
#
# 09__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 09__podium_speech_happy.mp4
#   Example manipulated: 09_02__podium_speech_happy__HIH8YA82.mp4
#
# 09__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 09__talking_against_wall.mp4
#   Example manipulated: 09_01__talking_against_wall__O8HNNX43.mp4
#
# 09__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 09__talking_angry_couch.mp4
#   Example manipulated: 09_01__talking_angry_couch__P70H1JB0.mp4
#
# 09__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 09__walk_down_hall_angry.mp4
#   Example manipulated: 09_13__walk_down_hall_angry__BVZGDFD8.mp4
#
# 09__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 17
#   Example original: 09__walking_down_street_outside_angry.mp4
#   Example manipulated: 09_27__walking_down_street_outside_angry__RC9KATOO.mp4
#
# 10__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 10__exit_phone_room.mp4
#   Example manipulated: 10_19__exit_phone_room__O2IKR6YM.mp4
#
# 10__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 10__kitchen_pan.mp4
#   Example manipulated: 10_22__kitchen_pan__EHARPYBT.mp4
#
# 10__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 10__kitchen_still.mp4
#   Example manipulated: 10_22__kitchen_still__1TXK09OY.mp4
#
# 10__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 10__outside_talking_pan_laughing.mp4
#   Example manipulated: 10_22__outside_talking_pan_laughing__G48B2EQ2.mp4
#
# 10__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 10__outside_talking_still_laughing.mp4
#   Example manipulated: 10_23__outside_talking_still_laughing__CU6SNBFZ.mp4
#
# 10__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 10__podium_speech_happy.mp4
#   Example manipulated: 10_22__podium_speech_happy__EHARPYBT.mp4
#
# 10__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 10__talking_against_wall.mp4
#   Example manipulated: 10_23__talking_against_wall__W02WYPCX.mp4
#
# 10__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 10__talking_angry_couch.mp4
#   Example manipulated: 10_19__talking_angry_couch__BVVPN5D5.mp4
#
# 10__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 10__walk_down_hall_angry.mp4
#   Example manipulated: 10_22__walk_down_hall_angry__C1U7OY5M.mp4
#
# 10__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 10__walking_down_street_outside_angry.mp4
#   Example manipulated: 10_22__walking_down_street_outside_angry__8YQ2EUQP.mp4
#
# 10__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 10__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 10_19__walking_outside_cafe_disgusted__FFXB67PI.mp4
#
# 11__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 11__exit_phone_room.mp4
#   Example manipulated: 11_07__exit_phone_room__PGC20QSY.mp4
#
# 11__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 11__kitchen_pan.mp4
#   Example manipulated: 11_13__kitchen_pan__XXKQ4XM0.mp4
#
# 11__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 11__kitchen_still.mp4
#   Example manipulated: 11_03__kitchen_still__P08VGHTA.mp4
#
# 11__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 11__outside_talking_pan_laughing.mp4
#   Example manipulated: 11_01__outside_talking_pan_laughing__WIZ7GKOD.mp4
#
# 11__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 11__outside_talking_still_laughing.mp4
#   Example manipulated: 11_20__outside_talking_still_laughing__GNK9UR8K.mp4
#
# 11__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 11__podium_speech_happy.mp4
#   Example manipulated: 11_02__podium_speech_happy__NZJ1YEWE.mp4
#
# 11__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 11__secret_conversation.mp4
#   Example manipulated: 11_01__secret_conversation__FCNL2OVP.mp4
#
# 11__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 11__talking_against_wall.mp4
#   Example manipulated: 11_13__talking_against_wall__61T622EK.mp4
#
# 11__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 11__talking_angry_couch.mp4
#   Example manipulated: 11_18__talking_angry_couch__JJ1YREUN.mp4
#
# 11__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 11__walk_down_hall_angry.mp4
#   Example manipulated: 11_18__walk_down_hall_angry__PT4YKO2R.mp4
#
# 11__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 11__walking_down_street_outside_angry.mp4
#   Example manipulated: 11_01__walking_down_street_outside_angry__9OM3VE0Y.mp4
#
# 11__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 11__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 11_21__walking_outside_cafe_disgusted__T7DK03O1.mp4
#
# 12__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 12__exit_phone_room.mp4
#   Example manipulated: 12_26__exit_phone_room__HEKDCIHW.mp4
#
# 12__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 12__hugging_happy.mp4
#   Example manipulated: 12_06__hugging_happy__3K21NFNM.mp4
#
# 12__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 12__kitchen_pan.mp4
#   Example manipulated: 12_04__kitchen_pan__B6YJ9IW1.mp4
#
# 12__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 12__kitchen_still.mp4
#   Example manipulated: 12_13__kitchen_still__BFH4F0N8.mp4
#
# 12__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 12__outside_talking_pan_laughing.mp4
#   Example manipulated: 12_02__outside_talking_pan_laughing__9D2ZHEKW.mp4
#
# 12__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 12__outside_talking_still_laughing.mp4
#   Example manipulated: 12_07__outside_talking_still_laughing__KAG65PEE.mp4
#
# 12__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 12__podium_speech_happy.mp4
#   Example manipulated: 12_02__podium_speech_happy__9D2ZHEKW.mp4
#
# 12__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 12__secret_conversation.mp4
#   Example manipulated: 12_20__secret_conversation__VD7BCF1U.mp4
#
# 12__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 12__talking_against_wall.mp4
#   Example manipulated: 12_13__talking_against_wall__O3SOWBCU.mp4
#
# 12__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 12__talking_angry_couch.mp4
#   Example manipulated: 12_26__talking_angry_couch__LI63E4TS.mp4
#
# 12__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 12__walk_down_hall_angry.mp4
#   Example manipulated: 12_13__walk_down_hall_angry__6G44TDN4.mp4
#
# 12__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 12__walking_and_outside_surprised.mp4
#   Example manipulated: 12_07__walking_and_outside_surprised__X9X7FAZG.mp4
#
# 12__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 12__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 12_25__walking_down_indoor_hall_disgust__FQE07ND1.mp4
#
# 12__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 12__walking_down_street_outside_angry.mp4
#   Example manipulated: 12_13__walking_down_street_outside_angry__2TM4IFSF.mp4
#
# 12__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 12__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 12_03__walking_outside_cafe_disgusted__D7G6YJON.mp4
#
# 13__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 13__exit_phone_room.mp4
#   Example manipulated: 13_15__exit_phone_room__X0EIIJF7.mp4
#
# 13__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 13__hugging_happy.mp4
#   Example manipulated: 13_11__hugging_happy__61T622EK.mp4
#
# 13__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 13__kitchen_pan.mp4
#   Example manipulated: 13_11__kitchen_pan__61T622EK.mp4
#
# 13__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 13__kitchen_still.mp4
#   Example manipulated: 13_04__kitchen_still__00T3UYOR.mp4
#
# 13__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 13__outside_talking_pan_laughing.mp4
#   Example manipulated: 13_27__outside_talking_pan_laughing__A1OSUJE9.mp4
#
# 13__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 13__outside_talking_still_laughing.mp4
#   Example manipulated: 13_25__outside_talking_still_laughing__IW9OFVMG.mp4
#
# 13__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 13__podium_speech_happy.mp4
#   Example manipulated: 13_12__podium_speech_happy__2TM4IFSF.mp4
#
# 13__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 13__secret_conversation.mp4
#   Example manipulated: 13_04__secret_conversation__00T3UYOR.mp4
#
# 13__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 13__talking_against_wall.mp4
#   Example manipulated: 13_09__talking_against_wall__LPT427RY.mp4
#
# 13__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 13__talking_angry_couch.mp4
#   Example manipulated: 13_11__talking_angry_couch__61T622EK.mp4
#
# 13__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 13__walk_down_hall_angry.mp4
#   Example manipulated: 13_12__walk_down_hall_angry__Q442U52P.mp4
#
# 13__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 13__walking_and_outside_surprised.mp4
#   Example manipulated: 13_25__walking_and_outside_surprised__PBM86HKZ.mp4
#
# 13__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 13__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 13_20__walking_down_indoor_hall_disgust__EV1V4ZQV.mp4
#
# 13__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 13__walking_down_street_outside_angry.mp4
#   Example manipulated: 13_02__walking_down_street_outside_angry__2YSYT2N3.mp4
#
# 13__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 13__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 13_18__walking_outside_cafe_disgusted__3II4T6H5.mp4
#
# 14__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 14__exit_phone_room.mp4
#   Example manipulated: 14_15__exit_phone_room__OMLZILK3.mp4
#
# 14__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 14__hugging_happy.mp4
#   Example manipulated: 14_13__hugging_happy__KMQ3AW6A.mp4
#
# 14__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 14__kitchen_pan.mp4
#   Example manipulated: 14_18__kitchen_pan__HYMNQ00Q.mp4
#
# 14__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 14__kitchen_still.mp4
#   Example manipulated: 14_21__kitchen_still__IRKML4J0.mp4
#
# 14__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 14__outside_talking_pan_laughing.mp4
#   Example manipulated: 14_06__outside_talking_pan_laughing__8U9ULZDT.mp4
#
# 14__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 14__outside_talking_still_laughing.mp4
#   Example manipulated: 14_15__outside_talking_still_laughing__4SO1CSAM.mp4
#
# 14__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 14__podium_speech_happy.mp4
#   Example manipulated: 14_02__podium_speech_happy__3IUBEKCT.mp4
#
# 14__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 14__secret_conversation.mp4
#   Example manipulated: 14_18__secret_conversation__A5A1Q467.mp4
#
# 14__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 14__talking_against_wall.mp4
#   Example manipulated: 14_03__talking_against_wall__38OVCK3X.mp4
#
# 14__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 14__talking_angry_couch.mp4
#   Example manipulated: 14_09__talking_angry_couch__6TEK3ZX0.mp4
#
# 14__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 14__walk_down_hall_angry.mp4
#   Example manipulated: 14_20__walk_down_hall_angry__B014BKVO.mp4
#
# 14__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 14__walking_and_outside_surprised.mp4
#   Example manipulated: 14_18__walking_and_outside_surprised__0YRBHIKG.mp4
#
# 14__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 14__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 14_20__walking_down_indoor_hall_disgust__R7SPX6OK.mp4
#
# 14__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 14__walking_down_street_outside_angry.mp4
#   Example manipulated: 14_21__walking_down_street_outside_angry__N0WM4GSV.mp4
#
# 14__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 14__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 14_02__walking_outside_cafe_disgusted__3IUBEKCT.mp4
#
# 15__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 15__exit_phone_room.mp4
#   Example manipulated: 15_06__exit_phone_room__QRCD27P8.mp4
#
# 15__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 15__hugging_happy.mp4
#   Example manipulated: 15_03__hugging_happy__T5SHH2UL.mp4
#
# 15__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 15__kitchen_pan.mp4
#   Example manipulated: 15_03__kitchen_pan__AIOM1U5V.mp4
#
# 15__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 15__kitchen_still.mp4
#   Example manipulated: 15_06__kitchen_still__E98QYYXO.mp4
#
# 15__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 15__outside_talking_pan_laughing.mp4
#   Example manipulated: 15_03__outside_talking_pan_laughing__AIOM1U5V.mp4
#
# 15__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 15__outside_talking_still_laughing.mp4
#   Example manipulated: 15_01__outside_talking_still_laughing__02HILKYO.mp4
#
# 15__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 15__podium_speech_happy.mp4
#   Example manipulated: 15_03__podium_speech_happy__Y11NT1YX.mp4
#
# 15__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 15__talking_against_wall.mp4
#   Example manipulated: 15_03__talking_against_wall__Q14RO7M7.mp4
#
# 15__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 15__talking_angry_couch.mp4
#   Example manipulated: 15_01__talking_angry_couch__02HILKYO.mp4
#
# 15__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 15__walk_down_hall_angry.mp4
#   Example manipulated: 15_03__walk_down_hall_angry__AIOM1U5V.mp4
#
# 15__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 15__walking_and_outside_surprised.mp4
#   Example manipulated: 15_01__walking_and_outside_surprised__02HILKYO.mp4
#
# 15__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 15__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 15_04__walking_down_indoor_hall_disgust__46TJ9IOJ.mp4
#
# 15__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 15__walking_down_street_outside_angry.mp4
#   Example manipulated: 15_03__walking_down_street_outside_angry__DG8ITQO3.mp4
#
# 15__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 15__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 15_14__walking_outside_cafe_disgusted__RNHLLKSQ.mp4
#
# 16__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 16__exit_phone_room.mp4
#   Example manipulated: 16_08__exit_phone_room__8Q7JCS95.mp4
#
# 16__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 16__hugging_happy.mp4
#   Example manipulated: 16_17__hugging_happy__S7UMSIQV.mp4
#
# 16__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 16__kitchen_pan.mp4
#   Example manipulated: 16_08__kitchen_pan__8Q7JCS95.mp4
#
# 16__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 16__kitchen_still.mp4
#   Example manipulated: 16_28__kitchen_still__U757192N.mp4
#
# 16__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 16__outside_talking_pan_laughing.mp4
#   Example manipulated: 16_17__outside_talking_pan_laughing__S7UMSIQV.mp4
#
# 16__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 16__podium_speech_happy.mp4
#   Example manipulated: 16_28__podium_speech_happy__6DWLCU6T.mp4
#
# 16__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 16__talking_against_wall.mp4
#   Example manipulated: 16_17__talking_against_wall__S7UMSIQV.mp4
#
# 16__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 16__walk_down_hall_angry.mp4
#   Example manipulated: 16_05__walk_down_hall_angry__V7BK27TX.mp4
#
# 16__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 16__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 16_08__walking_down_indoor_hall_disgust__8Q7JCS95.mp4
#
# 16__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 16__walking_down_street_outside_angry.mp4
#   Example manipulated: 16_05__walking_down_street_outside_angry__BY646B4R.mp4
#
# 16__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 16__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 16_17__walking_outside_cafe_disgusted__S7UMSIQV.mp4
#
# 17__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 17__exit_phone_room.mp4
#   Example manipulated: 17_16__exit_phone_room__S7UMSIQV.mp4
#
# 17__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 17__hugging_happy.mp4
#   Example manipulated: 17_05__hugging_happy__C4VHXZFY.mp4
#
# 17__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 17__kitchen_pan.mp4
#   Example manipulated: 17_05__kitchen_pan__M3H96PDQ.mp4
#
# 17__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 1
#   Example original: 17__kitchen_still.mp4
#   Example manipulated: 17_08__kitchen_still__ZCEYWYTC.mp4
#
# 17__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 17__outside_talking_pan_laughing.mp4
#   Example manipulated: 17_16__outside_talking_pan_laughing__S7UMSIQV.mp4
#
# 17__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 1
#   Example original: 17__outside_talking_still_laughing.mp4
#   Example manipulated: 17_08__outside_talking_still_laughing__PBVFRHF5.mp4
#
# 17__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 17__podium_speech_happy.mp4
#   Example manipulated: 17_08__podium_speech_happy__JZYRLJ8T.mp4
#
# 17__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 17__talking_against_wall.mp4
#   Example manipulated: 17_08__talking_against_wall__ISS1V0B1.mp4
#
# 17__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 1
#   Example original: 17__talking_angry_couch.mp4
#   Example manipulated: 17_08__talking_angry_couch__05AN86QA.mp4
#
# 17__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 17__walk_down_hall_angry.mp4
#   Example manipulated: 17_16__walk_down_hall_angry__S7UMSIQV.mp4
#
# 17__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 17__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 17_08__walking_down_indoor_hall_disgust__JZYRLJ8T.mp4
#
# 18__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 18__exit_phone_room.mp4
#   Example manipulated: 18_25__exit_phone_room__AUC0HY5T.mp4
#
# 18__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 18__kitchen_pan.mp4
#   Example manipulated: 18_06__kitchen_pan__5HNHMK6G.mp4
#
# 18__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 18__kitchen_still.mp4
#   Example manipulated: 18_06__kitchen_still__XJ76YU5A.mp4
#
# 18__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 18__outside_talking_pan_laughing.mp4
#   Example manipulated: 18_06__outside_talking_pan_laughing__OWJY9LQU.mp4
#
# 18__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 18__outside_talking_still_laughing.mp4
#   Example manipulated: 18_12__outside_talking_still_laughing__IKH1LBBY.mp4
#
# 18__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 18__podium_speech_happy.mp4
#   Example manipulated: 18_26__podium_speech_happy__UMEX6HWU.mp4
#
# 18__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 18__secret_conversation.mp4
#   Example manipulated: 18_02__secret_conversation__OXMEEFUQ.mp4
#
# 18__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 18__talking_against_wall.mp4
#   Example manipulated: 18_04__talking_against_wall__6J3ZFEJQ.mp4
#
# 18__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 18__walk_down_hall_angry.mp4
#   Example manipulated: 18_26__walk_down_hall_angry__C9VUQS9O.mp4
#
# 18__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 18__walking_down_street_outside_angry.mp4
#   Example manipulated: 18_11__walking_down_street_outside_angry__PT4YKO2R.mp4
#
# 18__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 18__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 18_06__walking_outside_cafe_disgusted__XJ76YU5A.mp4
#
# 19__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 19__exit_phone_room.mp4
#   Example manipulated: 19_24__exit_phone_room__59PN7WZ2.mp4
#
# 19__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 19__kitchen_pan.mp4
#   Example manipulated: 19_24__kitchen_pan__QD5K7BP2.mp4
#
# 19__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 19__kitchen_still.mp4
#   Example manipulated: 19_24__kitchen_still__0ZFOV5ZE.mp4
#
# 19__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 19__outside_talking_pan_laughing.mp4
#   Example manipulated: 19_22__outside_talking_pan_laughing__VK6BF5NV.mp4
#
# 19__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 19__outside_talking_still_laughing.mp4
#   Example manipulated: 19_24__outside_talking_still_laughing__NPZW2Z9L.mp4
#
# 19__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 19__podium_speech_happy.mp4
#   Example manipulated: 19_24__podium_speech_happy__LVZNRK9S.mp4
#
# 19__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 19__secret_conversation.mp4
#   Example manipulated: 19_24__secret_conversation__59PN7WZ2.mp4
#
# 19__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 19__talking_against_wall.mp4
#   Example manipulated: 19_22__talking_against_wall__VK6BF5NV.mp4
#
# 19__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 19__talking_angry_couch.mp4
#   Example manipulated: 19_10__talking_angry_couch__BVVPN5D5.mp4
#
# 19__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 19__walk_down_hall_angry.mp4
#   Example manipulated: 19_22__walk_down_hall_angry__VK6BF5NV.mp4
#
# 19__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 19__walking_down_street_outside_angry.mp4
#   Example manipulated: 19_10__walking_down_street_outside_angry__QNZIMEJH.mp4
#
# 19__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 19__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 19_23__walking_outside_cafe_disgusted__F7U8UY7V.mp4
#
# 20__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 20__exit_phone_room.mp4
#   Example manipulated: 20_25__exit_phone_room__MUS0X71T.mp4
#
# 20__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 18
#   Example original: 20__hugging_happy.mp4
#   Example manipulated: 20_21__hugging_happy__ZCB5OMEW.mp4
#
# 20__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 20__kitchen_pan.mp4
#   Example manipulated: 20_12__kitchen_pan__B0X1CGG2.mp4
#
# 20__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 20__kitchen_still.mp4
#   Example manipulated: 20_13__kitchen_still__NJEO6L5O.mp4
#
# 20__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 18
#   Example original: 20__outside_talking_pan_laughing.mp4
#   Example manipulated: 20_13__outside_talking_pan_laughing__LXLR1B6N.mp4
#
# 20__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 20__outside_talking_still_laughing.mp4
#   Example manipulated: 20_11__outside_talking_still_laughing__GNK9UR8K.mp4
#
# 20__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 8
# ...
#
# 22__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 1
#   Example original: 22__podium_speech_happy.mp4
#   Example manipulated: 22_10__podium_speech_happy__FY7YI0AJ.mp4
#
# 22__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 22__secret_conversation.mp4
#   Example manipulated: 22_10__secret_conversation__PUJR4HJ1.mp4
#
# 22__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 22__talking_against_wall.mp4
#   Example manipulated: 22_24__talking_against_wall__XL557XC6.mp4
#
# 22__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 22__walk_down_hall_angry.mp4
#   Example manipulated: 22_10__walk_down_hall_angry__FY7YI0AJ.mp4
#
# 22__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 22__walking_and_outside_surprised.mp4
#   Example manipulated: 22_10__walking_and_outside_surprised__C1U7OY5M.mp4
#
# 22__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 22__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 22_19__walking_down_indoor_hall_disgust__VK6BF5NV.mp4
#
# 22__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 22__walking_down_street_outside_angry.mp4
#   Example manipulated: 22_24__walking_down_street_outside_angry__7E3GY85F.mp4
#
# 22__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 22__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 22_23__walking_outside_cafe_disgusted__J8JK3NBV.mp4
#
# 23__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 23__exit_phone_room.mp4
#   Example manipulated: 23_22__exit_phone_room__10R2HRAU.mp4
#
# 23__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 23__hugging_happy.mp4
#   Example manipulated: 23_19__hugging_happy__H4SUVFTL.mp4
#
# 23__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 23__kitchen_pan.mp4
#   Example manipulated: 23_19__kitchen_pan__H4SUVFTL.mp4
#
# 23__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 23__kitchen_still.mp4
#   Example manipulated: 23_24__kitchen_still__YR5OVD4S.mp4
#
# 23__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 23__outside_talking_pan_laughing.mp4
#   Example manipulated: 23_10__outside_talking_pan_laughing__ZHJO34DY.mp4
#
# 23__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 23__outside_talking_still_laughing.mp4
#   Example manipulated: 23_19__outside_talking_still_laughing__D1K19NUP.mp4
#
# 23__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 23__podium_speech_happy.mp4
#   Example manipulated: 23_19__podium_speech_happy__D1K19NUP.mp4
#
# 23__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 23__secret_conversation.mp4
#   Example manipulated: 23_24__secret_conversation__MDSDXSNU.mp4
#
# 23__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 23__talking_against_wall.mp4
#   Example manipulated: 23_10__talking_against_wall__W4BDINQ5.mp4
#
# 23__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 23__talking_angry_couch.mp4
#   Example manipulated: 23_19__talking_angry_couch__D1K19NUP.mp4
#
# 23__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 23__walk_down_hall_angry.mp4
#   Example manipulated: 23_10__walk_down_hall_angry__ZHJO34DY.mp4
#
# 23__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 23__walking_and_outside_surprised.mp4
#   Example manipulated: 23_24__walking_and_outside_surprised__YR5OVD4S.mp4
#
# 23__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 23__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 23_10__walking_down_indoor_hall_disgust__GYY4VANY.mp4
#
# 23__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 23__walking_down_street_outside_angry.mp4
#   Example manipulated: 23_10__walking_down_street_outside_angry__W02WYPCX.mp4
#
# 23__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 23__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 23_19__walking_outside_cafe_disgusted__WHQ1229T.mp4
#
# 24__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 24__exit_phone_room.mp4
#   Example manipulated: 24_19__exit_phone_room__QD5K7BP2.mp4
#
# 24__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 24__kitchen_pan.mp4
#   Example manipulated: 24_23__kitchen_pan__YR5OVD4S.mp4
#
# 24__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 24__kitchen_still.mp4
#   Example manipulated: 24_23__kitchen_still__YR5OVD4S.mp4
#
# 24__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 24__outside_talking_pan_laughing.mp4
#   Example manipulated: 24_19__outside_talking_pan_laughing__59PN7WZ2.mp4
#
# 24__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 24__outside_talking_still_laughing.mp4
#   Example manipulated: 24_23__outside_talking_still_laughing__YR5OVD4S.mp4
#
# 24__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 24__podium_speech_happy.mp4
#   Example manipulated: 24_19__podium_speech_happy__QD5K7BP2.mp4
#
# 24__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 24__secret_conversation.mp4
#   Example manipulated: 24_19__secret_conversation__LVZNRK9S.mp4
#
# 24__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 24__talking_against_wall.mp4
#   Example manipulated: 24_22__talking_against_wall__XL557XC6.mp4
#
# 24__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 24__talking_angry_couch.mp4
#   Example manipulated: 24_19__talking_angry_couch__0ZFOV5ZE.mp4
#
# 24__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 24__walk_down_hall_angry.mp4
#   Example manipulated: 24_19__walk_down_hall_angry__OF8LF68K.mp4
#
# 24__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 24__walking_down_street_outside_angry.mp4
#   Example manipulated: 24_23__walking_down_street_outside_angry__YR5OVD4S.mp4
#
# 24__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 24__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 24_22__walking_outside_cafe_disgusted__XL557XC6.mp4
#
# 25__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 25__exit_phone_room.mp4
#   Example manipulated: 25_26__exit_phone_room__7ZRKCFMS.mp4
#
# 25__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 17
#   Example original: 25__outside_talking_pan_laughing.mp4
#   Example manipulated: 25_06__outside_talking_pan_laughing__3QQBVBYN.mp4
#
# 25__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 25__outside_talking_still_laughing.mp4
#   Example manipulated: 25_20__outside_talking_still_laughing__M86GQTHK.mp4
#
# 25__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 25__podium_speech_happy.mp4
#   Example manipulated: 25_26__podium_speech_happy__PQ41U3IJ.mp4
#
# 25__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 25__secret_conversation.mp4
#   Example manipulated: 25_02__secret_conversation__Z7FQ69VP.mp4
#
# 25__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 25__talking_against_wall.mp4
#   Example manipulated: 25_20__talking_against_wall__ZG0SRZOA.mp4
#
# 25__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 25__walk_down_hall_angry.mp4
#   Example manipulated: 25_11__walk_down_hall_angry__JX0SAMTC.mp4
#
# 25__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 25__walking_down_street_outside_angry.mp4
#   Example manipulated: 25_26__walking_down_street_outside_angry__XKQAYTLI.mp4
#
# 25__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 25__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 25_12__walking_outside_cafe_disgusted__G26LG5N7.mp4
#
# 26__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 26__exit_phone_room.mp4
#   Example manipulated: 26_04__exit_phone_room__MS2MLJP1.mp4
#
# 26__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 19
#   Example original: 26__kitchen_pan.mp4
#   Example manipulated: 26_09__kitchen_pan__C3K20JOL.mp4
#
# 26__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 26__kitchen_still.mp4
#   Example manipulated: 26_20__kitchen_still__34DJQS3E.mp4
#
# 26__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 26__outside_talking_pan_laughing.mp4
#   Example manipulated: 26_13__outside_talking_pan_laughing__WK3NZ3UV.mp4
#
# 26__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 14
#   Example original: 26__outside_talking_still_laughing.mp4
#   Example manipulated: 26_25__outside_talking_still_laughing__7ZRKCFMS.mp4
#
# 26__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 13
#   Example original: 26__podium_speech_happy.mp4
#   Example manipulated: 26_18__podium_speech_happy__UMEX6HWU.mp4
#
# 26__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 26__secret_conversation.mp4
#   Example manipulated: 26_04__secret_conversation__WX836VLY.mp4
#
# 26__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 26__talking_against_wall.mp4
#   Example manipulated: 26_27__talking_against_wall__IE9N0ZI9.mp4
#
# 26__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 16
#   Example original: 26__talking_angry_couch.mp4
#   Example manipulated: 26_25__talking_angry_couch__XKQAYTLI.mp4
#
# 26__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 15
#   Example original: 26__walk_down_hall_angry.mp4
#   Example manipulated: 26_14__walk_down_hall_angry__ILLP29ZH.mp4
#
# 26__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 26__walking_down_street_outside_angry.mp4
#   Example manipulated: 26_18__walking_down_street_outside_angry__UMEX6HWU.mp4
#
# 26__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 10
#   Example original: 26__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 26_25__walking_outside_cafe_disgusted__XKQAYTLI.mp4
#
# 27__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 27__exit_phone_room.mp4
#   Example manipulated: 27_02__exit_phone_room__6GC9HY9J.mp4
#
# 27__hugging_happy:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 27__hugging_happy.mp4
#   Example manipulated: 27_02__hugging_happy__UGO2181S.mp4
#
# 27__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 27__kitchen_pan.mp4
#   Example manipulated: 27_26__kitchen_pan__IE9N0ZI9.mp4
#
# 27__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 27__kitchen_still.mp4
#   Example manipulated: 27_13__kitchen_still__A1OSUJE9.mp4
#
# 27__meeting_serious:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 27__meeting_serious.mp4
#   Example manipulated: 27_26__meeting_serious__IE9N0ZI9.mp4
#
# 27__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 9
#   Example original: 27__outside_talking_pan_laughing.mp4
#   Example manipulated: 27_15__outside_talking_pan_laughing__WZ4MLUAV.mp4
#
# 27__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 27__outside_talking_still_laughing.mp4
#   Example manipulated: 27_25__outside_talking_still_laughing__1KU29EUL.mp4
#
# 27__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 27__podium_speech_happy.mp4
#   Example manipulated: 27_02__podium_speech_happy__FV8M8O2C.mp4
#
# 27__talking_against_wall:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 27__talking_against_wall.mp4
#   Example manipulated: 27_09__talking_against_wall__RC9KATOO.mp4
#
# 27__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 27__talking_angry_couch.mp4
#   Example manipulated: 27_02__talking_angry_couch__78M8S6M6.mp4
#
# 27__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 11
#   Example original: 27__walk_down_hall_angry.mp4
#   Example manipulated: 27_02__walk_down_hall_angry__FV8M8O2C.mp4
#
# 27__walking_and_outside_surprised:
#   Original videos: 1
#   Manipulated versions: 12
#   Example original: 27__walking_and_outside_surprised.mp4
#   Example manipulated: 27_20__walking_and_outside_surprised__LM907ECA.mp4
#
# 27__walking_down_indoor_hall_disgust:
#   Original videos: 1
#   Manipulated versions: 4
#   Example original: 27__walking_down_indoor_hall_disgust.mp4
#   Example manipulated: 27_18__walking_down_indoor_hall_disgust__NYHE8D0J.mp4
#
# 27__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 27__walking_down_street_outside_angry.mp4
#   Example manipulated: 27_06__walking_down_street_outside_angry__S3T7SK9O.mp4
#
# 27__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 8
#   Example original: 27__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 27_06__walking_outside_cafe_disgusted__S3T7SK9O.mp4
#
# 28__exit_phone_room:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 28__exit_phone_room.mp4
#   Example manipulated: 28_05__exit_phone_room__U9LRLJ6N.mp4
#
# 28__kitchen_pan:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 28__kitchen_pan.mp4
#   Example manipulated: 28_08__kitchen_pan__6HFK6PB4.mp4
#
# 28__kitchen_still:
#   Original videos: 1
#   Manipulated versions: 3
#   Example original: 28__kitchen_still.mp4
#   Example manipulated: 28_08__kitchen_still__HIOU8Z8I.mp4
#
# 28__outside_talking_pan_laughing:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 28__outside_talking_pan_laughing.mp4
#   Example manipulated: 28_08__outside_talking_pan_laughing__GGCUYQA4.mp4
#
# 28__outside_talking_still_laughing:
#   Original videos: 1
#   Manipulated versions: 1
#   Example original: 28__outside_talking_still_laughing.mp4
#   Example manipulated: 28_08__outside_talking_still_laughing__GQN9WHLD.mp4
#
# 28__podium_speech_happy:
#   Original videos: 1
#   Manipulated versions: 7
#   Example original: 28__podium_speech_happy.mp4
#   Example manipulated: 28_16__podium_speech_happy__ZA8XJIE9.mp4
#
# 28__secret_conversation:
#   Original videos: 1
#   Manipulated versions: 6
#   Example original: 28__secret_conversation.mp4
#   Example manipulated: 28_05__secret_conversation__W3J028UG.mp4
#
# 28__talking_angry_couch:
#   Original videos: 1
#   Manipulated versions: 2
#   Example original: 28__talking_angry_couch.mp4
#   Example manipulated: 28_08__talking_angry_couch__KXO8S7OP.mp4
#
# 28__walk_down_hall_angry:
#   Original videos: 1
#   Manipulated versions: 1
#   Example original: 28__walk_down_hall_angry.mp4
#   Example manipulated: 28_16__walk_down_hall_angry__X5FNCYON.mp4
#
# 28__walking_down_street_outside_angry:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 28__walking_down_street_outside_angry.mp4
#   Example manipulated: 28_16__walking_down_street_outside_angry__ZA8XJIE9.mp4
#
# 28__walking_outside_cafe_disgusted:
#   Original videos: 1
#   Manipulated versions: 5
#   Example original: 28__walking_outside_cafe_disgusted.mp4
#   Example manipulated: 28_16__walking_outside_cafe_disgusted__NAZP864W.mp4

# %%
def create_balanced_dataset(original_dict, manipulated_dict, matching_bases, output_dir='../DFD/balanced_dataset'):
    """Create a balanced dataset by copying matching pairs to a new directory"""
    # Create output directories
    os.makedirs(os.path.join(output_dir, 'original'), exist_ok=True)
    os.makedirs(os.path.join(output_dir, 'manipulated'), exist_ok=True)
    
    total_pairs = 0
    
    for base in matching_bases:
        orig_videos = original_dict[base]
        manip_videos = manipulated_dict[base]
        
        # Copy one matching pair for each base type
        if orig_videos and manip_videos:
            # Copy original
            src = os.path.join(original_path, orig_videos[0])
            dst = os.path.join(output_dir, 'original', orig_videos[0])
            shutil.copy2(src, dst)
            
            # Copy manipulated
            src = os.path.join(manipulated_path, manip_videos[0])
            dst = os.path.join(output_dir, 'manipulated', manip_videos[0])
            shutil.copy2(src, dst)
            
            total_pairs += 1
    
    print(f"Created balanced dataset with {total_pairs} pairs of videos")
    print(f"Output directory: {output_dir}")

# Create the balanced dataset
create_balanced_dataset(original_dict, manipulated_dict, matching_bases)
# Out:
# Created balanced dataset with 358 pairs of videos
# Output directory: ../DFD/balanced_dataset
